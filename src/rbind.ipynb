# %%
import pandas as pd

# %%
df22 = pd.read_csv('data/atp_matches_2022.csv')
df21 = pd.read_csv('data/atp_matches_2021.csv')
df20 = pd.read_csv('data/atp_matches_2020.csv')
df19 = pd.read_csv('data/atp_matches_2019.csv')
df18 = pd.read_csv('data/atp_matches_2018.csv')
df17 = pd.read_csv('data/atp_matches_2017.csv')
df16 = pd.read_csv('data/atp_matches_2016.csv')
df15 = pd.read_csv('data/atp_matches_2015.csv')
df14 = pd.read_csv('data/atp_matches_2014.csv')
df13 = pd.read_csv('data/atp_matches_2013.csv')
df12 = pd.read_csv('data/atp_matches_2012.csv')
df11 = pd.read_csv('data/atp_matches_2011.csv')
df10 = pd.read_csv('data/atp_matches_2010.csv')
df9 = pd.read_csv('data/atp_matches_2009.csv')
df8 = pd.read_csv('data/atp_matches_2008.csv')
df7 = pd.read_csv('data/atp_matches_2007.csv')
df6 = pd.read_csv('data/atp_matches_2006.csv')
df5 = pd.read_csv('data/atp_matches_2005.csv')

# %%
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2000 non-null   object
#  1   tourney_name        2000 non-null   object
#  2   surface             2000 non-null   object
#  3   draw_size           2000 non-null   int64
#  4   tourney_level       2000 non-null   object
#  5   tourney_date        2000 non-null   int64
#  6   match_num           2000 non-null   int64
#  7   winner_id           2000 non-null   int64
#  8   winner_seed         887 non-null    object
#  9   winner_entry        314 non-null    object
#  10  winner_name         2000 non-null   object
#  11  winner_hand         2000 non-null   object
#  12  winner_ht           1970 non-null   float64
#  13  winner_ioc          2000 non-null   object
#  14  winner_age          2000 non-null   float64
# ...

# %%
df21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2733 entries, 0 to 2732
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          2733 non-null   object
#  1   tourney_name        2733 non-null   object
#  2   surface             2733 non-null   object
#  3   draw_size           2733 non-null   int64
#  4   tourney_level       2733 non-null   object
#  5   tourney_date        2733 non-null   int64
#  6   match_num           2733 non-null   int64
#  7   winner_id           2733 non-null   int64
#  8   winner_seed         1165 non-null   float64
#  9   winner_entry        417 non-null    object
#  10  winner_name         2733 non-null   object
#  11  winner_hand         2731 non-null   object
#  12  winner_ht           2723 non-null   float64
#  13  winner_ioc          2733 non-null   object
#  14  winner_age          2733 non-null   float64
# ...

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          1462 non-null   object
#  1   tourney_name        1462 non-null   object
#  2   surface             1462 non-null   object
#  3   draw_size           1462 non-null   int64
#  4   tourney_level       1462 non-null   object
#  5   tourney_date        1462 non-null   int64
#  6   match_num           1462 non-null   int64
#  7   winner_id           1462 non-null   int64
#  8   winner_seed         578 non-null    float64
#  9   winner_entry        233 non-null    object
#  10  winner_name         1462 non-null   object
#  11  winner_hand         1462 non-null   object
#  12  winner_ht           1451 non-null   float64
#  13  winner_ioc          1462 non-null   object
#  14  winner_age          1462 non-null   float64
# ...

# %%
# df20 = df20.dropna(subset=['w_ace'])

# %%
data = pd.concat([df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22], ignore_index = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51523 entries, 0 to 51522
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          51523 non-null  object
#  1   tourney_name        51523 non-null  object
#  2   surface             51523 non-null  object
#  3   draw_size           51523 non-null  int64
#  4   tourney_level       51523 non-null  object
#  5   tourney_date        51523 non-null  int64
#  6   match_num           51523 non-null  int64
#  7   winner_id           51523 non-null  int64
#  8   winner_seed         22024 non-null  object
#  9   winner_entry        6505 non-null   object
#  10  winner_name         51523 non-null  object
#  11  winner_hand         51514 non-null  object
#  12  winner_ht           50566 non-null  float64
#  13  winner_ioc          51523 non-null  object
#  14  winner_age          51522 non-null  float64
# ...

# %%
data.to_csv('data/atp_matches_2005-2022.csv')
